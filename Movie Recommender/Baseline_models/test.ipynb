# %%
import pandas as pd
from data_loader import load_movies_with_tags

df = load_movies_with_tags()

# %%
df.columns
# Out:
# Index(['movieId', 'title', 'genres', 'title_clean', 'tag', 'text_features'], dtype='str')
